# %% [markdown]
# # Notes
# ## Questions
# * What would this API Client look like with normal Python `.py` files? Would we have it all in one big file or would we split it up a little over multiple, smaller files? Any rough sketch of what that may look like?
# * Could we have created a `BaseClient` class for the minimum parts (e.g., client authorization, etc.) and then create a `SpotifyAPIClient(BaseClient)` that inherits from this `BaseClient` for more generalized use? This way a `BaseClient` could be used/inherited inside multiple other API Clients?
# ## Authorization
# * Need to use `client_id` and `client_secret` to retrieve a auth token that will allow us to interact with the Spotify API service.
# * Typically authenticate once, retrieve a token which is then attached to your session. During your current session you'll be able to interact/make multiple requests with the service. This allows you to not have to login every time to access your session.
# * Handy [Authorization Flow Guide](https://developer.spotify.com/documentation/general/guides/authorization-guide/) from Spotify. We are buidling a **client** to interact with Spotify's API. You have to authenticate how a *user* authenticates with your *client* **and** Spotify at the same time (advanced - not covered fully in this tutorial). We're only using the **Client Credentials** flow, which requires a `Client ID` and `Secret Key` and we'll get in return an `Access Token`. This approach won't give give access to manage private user data, just general data only.
# * Our **client** is the application we're building and it (the app) needs to request authorization by sending a `POST` request.
# * `base64` is a more secure string format. For non-Base 64 encoded strings, you generally can build something like `client_creds = f"{client_id}:{client_secret}"`. You can encode/decode `str` to bytes using `str.encode()` and `str.encode().decode()`. The Spotify backend API is going to take our base64 encoded `str` (not `bytes`) we pass and then `base64.base64decode()` to verify credentials. Steps to do this:
#     1. First take `str` and encode to `bytes` using `str.encode()`
#     2. Then encode this bytestring to base64 using `base64.b64encode(bytestring)`
#     3. Next, decode this base64 `bytes` so it's back to `str` using `client_creds_b64.decode()` (**not** `b64decode()`).
# * The token response data we get after making the `POST` request to authorize our client has the `access_token` and the `expires_in` (seconds) details. We can use `datetime` and the `timedelta(seconds=expires_in)` to create an easy `expires` `datetime.datetime` object for tracking. We can check whether our token expired and to fetch a new one: `did_expire: bool = expires < now`.
# ## Base API Client Class
# * Once we have our `access_token` then we can use it. However, the `expires` and `access_tokens` are **state-like** items, so they will change over time. So, better would be to create a `BaseClient` **class** that can adjust/respond to these state changes in order to make our API calls through the class (and its methods) rather than just through simple functions like we did in `Auth.ipynb`. We're going to turn our functions into class methods.
# * Create our first class `SpotifyAPI(object)` with some general-purpose variables (nothing hard-coded since we want to reuse this for various sessions). We can pass the `client_id` and `client_secret` to the `__init__` function. The `super().__init__(*args, **kwargs)` allows us to call the class our class is inheriting from *directly*. Currently we're not doing that but in the future if we wanted to then having this line allows us to do that.
# * ?? We set `client_id` and `client_secret` to `None` by default for the class. However, we need to **update** them...?? Aren't these already available though since we set them inside the __init__ function? I think so but this makes it cleaner so we don't have to `{self.client_id}`? Not sure though as he mentioned "updating" these values...
#     * I *believe* we have to update the class variables within these methods because when we initialize/create a new instance of the class, we only pass in `client_id` and `client_secret` (based on our `__init__`). However, the other class variables (`access_token`, `expires`, etc.) are defaulted to `None` so our class methods need to update these values e.g, `self.access_token = access_token` (once we have retrieved the true `access_token`).
# * **Refactor** Could refactor the base class to have a method that handles the response data instead of all within the current `perform_authorization()` method.
# * **Refactor** Need to improve how we get the `access_token` because when it does expire, ideally it will go fetch another one automatically by re-performing this authorization function again.
# * Eventually going to take this base class and expand it to allow for something like `client.search` (`spotify.search`).
# ## Use the Access Token
# * Following the [Web API](https://developer.spotify.com/documentation/web-api/reference/) docs.
# * Once we get our `access_token` after `perform_authorization()`, the `token_type: "bearer"` instead of `Basic`. So, the initial `token_headers` header of `Authorization` had a `Basic` type. After we perform authorization, we receive `token_type: "bearer"`. This means we use `bearer` token moving forward.
# * We're essentially authorized to interact with the API via our new Client app. That means for each request we make to say, search for various songs or albums, we need to have this `bearer` token attached. Also, for Spotify specifically, we build up a request to query but we pass in all the `data` *directly* inside the `endpoint`/`lookup_url` we pass to `requests.get()`.
#     * To create this `lookup_url` string, we're going to use `from urllib.parse import urlencode` to help.
# * We now authenicated and worked with the API via our base class (client app). We have a working example of using the `search` endpoint of the API. However, we don't want to copy/paste the request code each time. Better would be to refactor/improve our `client`/`spotify` app (class) by adding some more helper/utility/convenience class methods to perform these searches, auto-refresh/fetch our `access_token` when it expires, and even allow accessing other endpoints (`artists`, `/v1/albums/{id}`, etc.).
# ## Resource-Enabled Client
# * We now authenicated and worked with the API via our base class (client app). We have a working example of using the `search` endpoint of the API. However, we don't want to copy/paste the request code each time. Better would be to refactor/improve our `client`/`spotify` app (class) by adding some more helper/utility/convenience class methods to perform these searches, auto-refresh/fetch our `access_token` when it expires, and even allow accessing other endpoints (`artists`, `/v1/albums/{id}`, etc.).
# * Need to add a `get_access_token()` method and `search()` method. Our `perform_authorization()` method doesn't actually return the `access_token` -- it's currently just stored in `self.access_token` so better would be to create a new method specific to getting it and then using it within our authorization based on whether it was successfully retrieved.
# * Add an additional attribute to our class (client) e.g., `def get_album()`, `def get_artist()` etc. So far we're only using the `Search` endpoint provided by Spotify's API. There [are a lot of other](https://developer.spotify.com/documentation/web-api/reference/search/search/) endpoints such as `Albums`, `Artists` etc. we could access.
# * Since there is an obvious pattern to accessing the `Albums` and `Artists` endpoints, let's create another method `def get_resource()` that is a more generalized method where we can pass the `resource_type` (e.g., `album` or ` artist`) and the `_id`.
# * Again, each request we make must be authorized and once we're (our client) is authorized, we have to attach/add an `"Authorization": "Bearer {access_token}"` `header` within our `request`. Since this `header` is required for every request, better would be to refactor and create an additional helper/convenience method `get_resource_header` (or could be called `get_access_header`, etc.).
# * **Challenge** Could expand by making a sub-class (another object?) for artists and albums themselves so we can get even more data about them.

# %%
import typing as t
import requests
import base64
import datetime
from urllib.parse import urlencode

# %%
# Snag creds from developer.spotify.com dashboard
client_id: str
client_secret: str

# %%
# Declare our first class with helper methods
class SpotifyAPIClient(object):
    access_token: str = None
    access_token_expires = datetime.datetime.now()  # or None
    access_token_did_expire: bool = True
    client_id: str = None
    client_secret: str = None
    token_url: str = "https://accounts.spotify.com/api/token"

    def __init__(self, client_id, client_secret, *args, **kwargs):
        # Call super() so we can call any class we inherit from directly!
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self) -> str:
        """
        Returns a Base 64 encoded string (not bytes!)
        """
        # Need to declare our client_id and client_secret vars
        # The self obj has them but need to update within this
        # method's scope:
        # NOTE ?? Aren't these already available though since we
        # set them inside the __init__ function? I think so but
        # this makes it cleaner so we don't have to {self.client_id}??
        client_id: str = self.client_id
        client_secret: str = self.client_secret

        # Update the client_id and client_secret values
        if client_id is None or client_secret is None:
            raise Exception("You must set client_id and client_secret.")

        # Build the credentials str required by Spotify:
        client_creds: str = f"{client_id}:{client_secret}"
        client_creds_bytes: bytes = client_creds.encode()
        client_creds_b64: bytes = base64.b64encode(client_creds_bytes)
        # NOTE We must .decode() back to 'str' type instead of 'bytes'
        client_creds_b64_decoded: str = client_creds_b64.decode()

        return client_creds_b64_decoded

    def get_token_headers(self) -> t.Dict:
        """
        Pass 'Authorization' header with b64 encoded creds
        "Authorization": "Basic <base64 encoded client_id:client_secret>"
        """
        client_creds_b64_decoded: str = self.get_client_credentials()

        token_headers: t.Dict = {
            "Content-Type": "application/x-www-form-urlencoded",
            "Authorization": f"Basic {client_creds_b64_decoded}"
        }

        return token_headers
    
    def get_token_data(self) -> t.Dict:
        token_data: t.Dict = {
            "grant_type": "client_credentials",
        }

        return token_data

    def perform_authorization(self) -> bool:
        """
        Extracts the access token and other variables for authorizing
        the client app with Spotify API. It uses helper methods to get
        client credentials, convert to Base 64, get token headers and
        token data. 
        """
        # TODO Re-run authorization if access_token expires
        # Use helper methods to retrieve components for sending request
        token_url: str = self.token_url
        token_data: t.Dict = self.get_token_data()
        token_headers: t.Dict = self.get_token_headers()

        # Now we have everything for authentication so it's time to make the POST request
        r = requests.post(token_url, data=token_data, headers=token_headers)

        if r.status_code not in range(200, 299):
            raise Exception(f"Could not authenticate client: {status_code}")
            # return False

        # Let's store the access token, expires in (seconds), etc.
        data: t.Dict = r.json()
        now = datetime.datetime.now()
        access_token: str = data['access_token']
        expires_in: float = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)

        # Update our class variables with these updated values
        self.access_token = access_token
        self.access_token_expires = expires  # datetime.datetime obj
        self.access_token_did_expire = expires < now  # refetch the token if True

        return True  # authorization successful

    def get_access_token(self) -> str:
        """
        Retrieve the authorized access token for our client app.
        """
        token: str = self.access_token
        expires = self.access_token_expires  # datetime
        now = datetime.datetime.now()

        if expires < now:
            # Retrieve by re-running this exact function!
            self.perform_authorization()
            return self.get_access_token()
        elif token is None:
            self.perform_authorization()
            return self.get_access_token()
        return token
    
    def get_resource_headers(self) -> t.Dict:
        """
        Retrieve the authorized access headers for our client app.
        Specifically, retrieve the Authorization header with the
        Bearer token. This is the header we want/need to pass for
        all of our resources/endpoints we access.
        """
        access_token: str = self.get_access_token()
        headers: t.Dict = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers



    def get_resource(self, lookup_id: str, resource_type: str = "albums", api_version: str = "v1") -> t.Dict:
        """
        Generalized method for retrieving a single artist or album,
        based on the resource type and id value. Must use an
        authorized client in order to access resource type.

        Params:
            _id = ID of the resource
            resource_type = Spotify API endpoint/resource to access
        """
        assert resource_type.lower() in ["artists", "albums"]
        base_url: str = "https://api.spotify.com"
        endpoint: str = f"{base_url}/{api_version}/{resource_type}/{lookup_id}"
        headers: t.Dict = self.get_resource_headers()

        # We have the pieces let's now build our request
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            print(f"Failed request: {r.status_code} : {endpoint}")
            return {}
        return r.json()

    
    def get_album(self, _id: str):
        """
        Search for a single album via Spotify's Albums endpoint:
        https://api.spotify.com/v1/albums/{id}
        """
        # === OLD reference only ===
        # base_url: str = "https://api.spotify.com/"
        # endpoint: str = f"{base_url}/v1/albums/{_id}"
        # r = requests.get(endpoint)
        # if r.status_code not in range(200, 299):
        #     return {}
        # return r.json()

        return self.get_resource(lookup_id=_id, resource_type="albums")

    def get_artist(self, _id: str):
        """
        Search for a single artist via Spotify's Artists endpoint:
        https://api.spotify.com/v1/artists/{id}
        """
        return self.get_resource(lookup_id=_id, resource_type="artists")


        
    def search(self, query: str, search_type: str = 'artist'):
        """
        Search the Spotify API for various songs, artists,
        albums, etc.

        Params:
            query- Query string that gets url encoded
            search_type - Default='artist'. Type of search to perform in Spotify
        """
        assert search_type.lower() in ["artist", "track", "playlist", "album", "show", "episode"]
        # Use our helper method to retrieve resource headers
        # which has the Bearer token inside
        headers: t.Dict = self.get_resource_headers()
        endpoint: str = "https://api.spotify.com/v1/search"

        # We need to pass our 'data' within the url string we send our GET request to
        # To make this easier we use urlencode
        # NOTE Could consider having 'type' be a List or Dict for more options
        data: str = urlencode({
            "q": query,
            "type": search_type.lower()  # "Track" -> "track"
        })

        # Let's build/concat our 'lookup_url' for use. Don't forget '?' symbol!
        lookup_url: str = f"{endpoint}?{data}"

        # Now that we have the bare minimum requirements, let's make a request
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            print(f"Failed request: {r.status_code} : {lookup_url}")
            return {}
        return r.json()

# %%
# Now let's test out our base class (client app)
# client = SpotifyAPI(client_id, client_secret)
# Could generalize this client for multiple services
spotify = SpotifyAPIClient(client_id, client_secret)

# %%
# Test out our new search() method
spotify.search(query="A lannister always pays his debts", search_type="track")
# Out:
#   'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2JgKlCS2glC37XDWreeCy2'},
#      'href': 'https://api.spotify.com/v1/albums/2JgKlCS2glC37XDWreeCy2',
#      'id': '2JgKlCS2glC37XDWreeCy2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27342a847dc8ca888c02ca4488f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0242a847dc8ca888c02ca4488f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485142a847dc8ca888c02ca4488f',
#        'width': 64}],
#      'name': 'Cinematic Chillout - Relaxing Soundtracks Music',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:2JgKlCS2glC37XDWreeCy2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#       'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#       'id': '6i9KFEJuHq78nMsQxeB1vR',
#       'name': 'NDR Radiophilharmonie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#       'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#       'id': '7BuKIq2YqVZhxSdquEnwko',
#       'name': 'Ben Palmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174960,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE861903694'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gUQFT9oorgKymSytDyHf5'},
#     'href': 'https://api.spotify.com/v1/tracks/7gUQFT9oorgKymSytDyHf5',
#     'id': '7gUQFT9oorgKymSytDyHf5',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37f4bdd8884ddf7b2e1711d2be4ffc46313d739e?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:7gUQFT9oorgKymSytDyHf5'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3gJsGz5u4v0xdd92NWnWku'},
#      'href': 'https://api.spotify.com/v1/albums/3gJsGz5u4v0xdd92NWnWku',
#      'id': '3gJsGz5u4v0xdd92NWnWku',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f7564ef3332704bc9f040c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f7564ef3332704bc9f040c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f7564ef3332704bc9f040c1',
#        'width': 64}],
#      'name': 'Music from Cult TV Shows',
#      'release_date': '2017-07-07',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:3gJsGz5u4v0xdd92NWnWku'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47G5hK3XB0uqQTAGOLSHIV'},
#       'href': 'https://api.spotify.com/v1/artists/47G5hK3XB0uqQTAGOLSHIV',
#       'id': '47G5hK3XB0uqQTAGOLSHIV',
#       'name': 'TV Sounds Unlimited',
#       'type': 'artist',
#       'uri': 'spotify:artist:47G5hK3XB0uqQTAGOLSHIV'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 169063,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMVRR1600669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2vcNLpHyOntxFV0e4AVXNo'},
#     'href': 'https://api.spotify.com/v1/tracks/2vcNLpHyOntxFV0e4AVXNo',
#     'id': '2vcNLpHyOntxFV0e4AVXNo',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts (From "Game of Thrones")',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7b1783330d6dea5cbc4b4d9c6977476efce08a6a?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2vcNLpHyOntxFV0e4AVXNo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dOnTTVTbQlFWF6yfD4Vw5'},
#        'href': 'https://api.spotify.com/v1/artists/6dOnTTVTbQlFWF6yfD4Vw5',
#        'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#        'name': 'daigoro789',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dOnTTVTbQlFWF6yfD4Vw5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UnbMm1SzcGhzu6tPrXIhP'},
#      'href': 'https://api.spotify.com/v1/albums/0UnbMm1SzcGhzu6tPrXIhP',
#      'id': '0UnbMm1SzcGhzu6tPrXIhP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739932241bf9a6c3e3f0f06d7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029932241bf9a6c3e3f0f06d7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519932241bf9a6c3e3f0f06d7c',
#        'width': 64}],
#      'name': 'Game of Thrones (Soundtrack for Piano)',
#      'release_date': '2019-02-08',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0UnbMm1SzcGhzu6tPrXIhP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dOnTTVTbQlFWF6yfD4Vw5'},
#       'href': 'https://api.spotify.com/v1/artists/6dOnTTVTbQlFWF6yfD4Vw5',
#       'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#       'name': 'daigoro789',
#       'type': 'artist',
#       'uri': 'spotify:artist:6dOnTTVTbQlFWF6yfD4Vw5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 160874,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ22B2065255'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2uJHav01WtdXJUTZ2gm0Sm'},
#     'href': 'https://api.spotify.com/v1/tracks/2uJHav01WtdXJUTZ2gm0Sm',
#     'id': '2uJHav01WtdXJUTZ2gm0Sm',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts (From "Game of Thrones") [For Piano Solo]',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/23dffde54953635a65220e22bba7c6193d24e620?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2uJHav01WtdXJUTZ2gm0Sm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dOnTTVTbQlFWF6yfD4Vw5'},
#        'href': 'https://api.spotify.com/v1/artists/6dOnTTVTbQlFWF6yfD4Vw5',
#        'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#        'name': 'daigoro789',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dOnTTVTbQlFWF6yfD4Vw5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2s7CaLdM029QMixEmwIK8B'},
#      'href': 'https://api.spotify.com/v1/albums/2s7CaLdM029QMixEmwIK8B',
#      'id': '2s7CaLdM029QMixEmwIK8B',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e696e5de6fa3b0b8d23a83a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e696e5de6fa3b0b8d23a83a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e696e5de6fa3b0b8d23a83a',
#        'width': 64}],
#      'name': 'Game of Thrones Soundtrack for Flute & Piano Duet',
#      'release_date': '2019-03-04',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2s7CaLdM029QMixEmwIK8B'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dOnTTVTbQlFWF6yfD4Vw5'},
#       'href': 'https://api.spotify.com/v1/artists/6dOnTTVTbQlFWF6yfD4Vw5',
#       'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#       'name': 'daigoro789',
#       'type': 'artist',
#       'uri': 'spotify:artist:6dOnTTVTbQlFWF6yfD4Vw5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161979,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ22B2074602'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2RI0QtI8qArV8fFPkTCIuN'},
#     'href': 'https://api.spotify.com/v1/tracks/2RI0QtI8qArV8fFPkTCIuN',
#     'id': '2RI0QtI8qArV8fFPkTCIuN',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts (From "Game of Thrones") [For Flute & Piano Duet]',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4464155460a798aa1b278dbe7d463736e57d7cc3?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2RI0QtI8qArV8fFPkTCIuN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mT4rQiMcGq6OCOhjK4CYc'},
#        'href': 'https://api.spotify.com/v1/artists/0mT4rQiMcGq6OCOhjK4CYc',
#        'id': '0mT4rQiMcGq6OCOhjK4CYc',
#        'name': 'Philharmonic Wind Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:0mT4rQiMcGq6OCOhjK4CYc'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/70fOSWnrIv5pImxpKDtPx6'},
#        'href': 'https://api.spotify.com/v1/artists/70fOSWnrIv5pImxpKDtPx6',
#        'id': '70fOSWnrIv5pImxpKDtPx6',
#        'name': 'Marc Reift Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:70fOSWnrIv5pImxpKDtPx6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Z6T9u4KPdqth9kNrbTPxI'},
#      'href': 'https://api.spotify.com/v1/albums/4Z6T9u4KPdqth9kNrbTPxI',
#      'id': '4Z6T9u4KPdqth9kNrbTPxI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736bcd3130717a24b0b9e6e6d7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026bcd3130717a24b0b9e6e6d7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516bcd3130717a24b0b9e6e6d7',
#        'width': 64}],
#      'name': 'Cinemagic 50',
#      'release_date': '2016-04-26',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4Z6T9u4KPdqth9kNrbTPxI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mT4rQiMcGq6OCOhjK4CYc'},
#       'href': 'https://api.spotify.com/v1/artists/0mT4rQiMcGq6OCOhjK4CYc',
#       'id': '0mT4rQiMcGq6OCOhjK4CYc',
#       'name': 'Philharmonic Wind Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:0mT4rQiMcGq6OCOhjK4CYc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/70fOSWnrIv5pImxpKDtPx6'},
#       'href': 'https://api.spotify.com/v1/artists/70fOSWnrIv5pImxpKDtPx6',
#       'id': '70fOSWnrIv5pImxpKDtPx6',
#       'name': 'Marc Reift Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:70fOSWnrIv5pImxpKDtPx6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 378917,
#     'explicit': False,
#     'external_ids': {'isrc': 'CH1601608942'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/44fC2dp8Z5BkTq3aickCuy'},
#     'href': 'https://api.spotify.com/v1/tracks/44fC2dp8Z5BkTq3aickCuy',
#     'id': '44fC2dp8Z5BkTq3aickCuy',
#     'is_local': False,
#     'name': 'Main Title / The King\'s Arrival / Stand and Fight / A Lannister Always Pays His Debts / Finale (From "Game of Thrones")',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3a8d3168cbb03c53b4aebd52607468a2706aaa0f?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:44fC2dp8Z5BkTq3aickCuy'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=A+lannister+always+pays+his+debts&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 60}}

# %%
# Let's test out our new get_album, get_artist methods
spotify.get_artist("1w5Kfo2jwwIPruYS2UWh56")  # Pearl Jam
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#  'followers': {'href': None, 'total': 5907203},
#  'genres': ['alternative rock', 'grunge', 'permanent wave', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#  'id': '1w5Kfo2jwwIPruYS2UWh56',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/8a7775f16a99af5d353d4eb31ec0ccf908a6a6d1',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/7d40296db84567ff1f76c6bb3a561de53bccadb3',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/4733adb065f2e5c637bf7362413e9d2a9e330310',
#    'width': 160}],
#  'name': 'Pearl Jam',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}

# %%
spotify.get_artist("1hCkSJcXREhrodeIHQdav8")  # Ramin Djawadi
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#  'followers': {'href': None, 'total': 426151},
#  'genres': ['german soundtrack',
#   'scorecore',
#   'soundtrack',
#   'video game music'],
#  'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#  'id': '1hCkSJcXREhrodeIHQdav8',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/3192cec3d51144c7a061848927f89983835c5480',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/d33c97f0483a37ecf2d8309f99b1abaa1e499fd9',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/553f6b2aa9cb60ac1353f8efbd9edf3542332e8f',
#    'width': 160}],
#  'name': 'Ramin Djawadi',
#  'popularity': 73,
#  'type': 'artist',
#  'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}

# %%
spotify.get_album("2JgKlCS2glC37XDWreeCy2")
# Out:
# kets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 368826,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5fwWzep2gLXZbRbNswJwhD'},
#     'href': 'https://api.spotify.com/v1/tracks/5fwWzep2gLXZbRbNswJwhD',
#     'id': '5fwWzep2gLXZbRbNswJwhD',
#     'is_local': False,
#     'name': 'I giorni: Andante',
#     'preview_url': 'https://p.scdn.co/mp3-preview/d0329016bea71e1fbecff88c80f5c31e24cc6a87?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:5fwWzep2gLXZbRbNswJwhD'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/566MlWaCa63jvMZV9YMj3V'},
#       'href': 'https://api.spotify.com/v1/artists/566MlWaCa63jvMZV9YMj3V',
#       'id': '566MlWaCa63jvMZV9YMj3V',
#       'name': 'Joseph Trapanese',
#       'type': 'artist',
#       'uri': 'spotify:artist:566MlWaCa63jvMZV9YMj3V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 81320,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UqgKg6vNLimbKiEeH0t14'},
#     'href': 'https://api.spotify.com/v1/tracks/1UqgKg6vNLimbKiEeH0t14',
#     'id': '1UqgKg6vNLimbKiEeH0t14',
#     'is_local': False,
#     'name': 'Life',
#     'preview_url': 'https://p.scdn.co/mp3-preview/39d6c959deba4b88e55c7d31c18861ad1c763480?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:1UqgKg6vNLimbKiEeH0t14'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0qudezVgvl4Chd9BgNFB83'},
#       'href': 'https://api.spotify.com/v1/artists/0qudezVgvl4Chd9BgNFB83',
#       'id': '0qudezVgvl4Chd9BgNFB83',
#       'name': 'Chilly Gonzales',
#       'type': 'artist',
#       'uri': 'spotify:artist:0qudezVgvl4Chd9BgNFB83'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#       'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#       'id': '6i9KFEJuHq78nMsQxeB1vR',
#       'name': 'NDR Radiophilharmonie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4GWgKyhb1WuUWPTtPrLnVJ'},
#       'href': 'https://api.spotify.com/v1/artists/4GWgKyhb1WuUWPTtPrLnVJ',
#       'id': '4GWgKyhb1WuUWPTtPrLnVJ',
#       'name': 'Sebastian Knauer',
#       'type': 'artist',
#       'uri': 'spotify:artist:4GWgKyhb1WuUWPTtPrLnVJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hi3goRhw04R2VLGjvNrd6'},
#       'href': 'https://api.spotify.com/v1/artists/0hi3goRhw04R2VLGjvNrd6',
#       'id': '0hi3goRhw04R2VLGjvNrd6',
#       'name': 'Michael England',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hi3goRhw04R2VLGjvNrd6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224373,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2udeYsPeyRLru9ZvlkH29K'},
#     'href': 'https://api.spotify.com/v1/tracks/2udeYsPeyRLru9ZvlkH29K',
#     'id': '2udeYsPeyRLru9ZvlkH29K',
#     'is_local': False,
#     'name': 'Advantage Points',
#     'preview_url': 'https://p.scdn.co/mp3-preview/080d3376bf7f1f8473225957b1f0b08b07090dac?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:2udeYsPeyRLru9ZvlkH29K'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YC192cP3KPCRWx8zr8MfZ'},
#       'href': 'https://api.spotify.com/v1/artists/0YC192cP3KPCRWx8zr8MfZ',
#       'id': '0YC192cP3KPCRWx8zr8MfZ',
#       'name': 'Hans Zimmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YC192cP3KPCRWx8zr8MfZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3BWSxj4tXD0yENwYVwxYO7'},
#       'href': 'https://api.spotify.com/v1/artists/3BWSxj4tXD0yENwYVwxYO7',
#       'id': '3BWSxj4tXD0yENwYVwxYO7',
#       'name': 'Pedro Eustache',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BWSxj4tXD0yENwYVwxYO7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2nJZffRcm3WDa74FSkYYOb'},
#       'href': 'https://api.spotify.com/v1/artists/2nJZffRcm3WDa74FSkYYOb',
#       'id': '2nJZffRcm3WDa74FSkYYOb',
#       'name': 'Vienna Radio Symphony Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:2nJZffRcm3WDa74FSkYYOb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4htujiPBxC6ynIY9V6sKOR'},
#       'href': 'https://api.spotify.com/v1/artists/4htujiPBxC6ynIY9V6sKOR',
#       'id': '4htujiPBxC6ynIY9V6sKOR',
#       'name': 'Martin Gellner',
#       'type': 'artist',
#       'uri': 'spotify:artist:4htujiPBxC6ynIY9V6sKOR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 126413,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6SLUHVbSN05JErmxBoW1Fn'},
#     'href': 'https://api.spotify.com/v1/tracks/6SLUHVbSN05JErmxBoW1Fn',
#     'id': '6SLUHVbSN05JErmxBoW1Fn',
#     'is_local': False,
#     'name': 'Kung Fu Panda: Oogway Ascends - Orchestra Version - Live',
#     'preview_url': 'https://p.scdn.co/mp3-preview/927f6e11e76c4958b921b12ab87ed54636d873e7?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:6SLUHVbSN05JErmxBoW1Fn'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oLXPtqJveGbowHgv9g0Y8'},
#       'href': 'https://api.spotify.com/v1/artists/5oLXPtqJveGbowHgv9g0Y8',
#       'id': '5oLXPtqJveGbowHgv9g0Y8',
#       'name': 'Vladimir Martynov',
#       'type': 'artist',
#       'uri': 'spotify:artist:5oLXPtqJveGbowHgv9g0Y8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4M2W6hcJWi6Nrd3XelpO3F'},
#       'href': 'https://api.spotify.com/v1/artists/4M2W6hcJWi6Nrd3XelpO3F',
#       'id': '4M2W6hcJWi6Nrd3XelpO3F',
#       'name': 'Eldbjørg Hemsing',
#       'type': 'artist',
#       'uri': 'spotify:artist:4M2W6hcJWi6Nrd3XelpO3F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#       'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#       'id': '6i9KFEJuHq78nMsQxeB1vR',
#       'name': 'NDR Radiophilharmonie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hi3goRhw04R2VLGjvNrd6'},
#       'href': 'https://api.spotify.com/v1/artists/0hi3goRhw04R2VLGjvNrd6',
#       'id': '0hi3goRhw04R2VLGjvNrd6',
#       'name': 'Michael England',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hi3goRhw04R2VLGjvNrd6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 334653,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2KLa8iFvWA4aMLZBfdDSBJ'},
#     'href': 'https://api.spotify.com/v1/tracks/2KLa8iFvWA4aMLZBfdDSBJ',
#     'id': '2KLa8iFvWA4aMLZBfdDSBJ',
#     'is_local': False,
#     'name': 'Come In!: IV. Movement',
#     'preview_url': 'https://p.scdn.co/mp3-preview/8c60a7e023da7daa4a99908c5e48426b005b56ac?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:2KLa8iFvWA4aMLZBfdDSBJ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sK0i9UQeU4aPaxgGTFTcC'},
#       'href': 'https://api.spotify.com/v1/artists/0sK0i9UQeU4aPaxgGTFTcC',
#       'id': '0sK0i9UQeU4aPaxgGTFTcC',
#       'name': 'Andrew Lockington',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sK0i9UQeU4aPaxgGTFTcC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4oKiOJ0qPP6TFCv6ebRFKO'},
#       'href': 'https://api.spotify.com/v1/artists/4oKiOJ0qPP6TFCv6ebRFKO',
#       'id': '4oKiOJ0qPP6TFCv6ebRFKO',
#       'name': 'Nicholas Dodd',
#       'type': 'artist',
#       'uri': 'spotify:artist:4oKiOJ0qPP6TFCv6ebRFKO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 363693,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6hwls26jMYEIh6yxiu7Ack'},
#     'href': 'https://api.spotify.com/v1/tracks/6hwls26jMYEIh6yxiu7Ack',
#     'id': '6hwls26jMYEIh6yxiu7Ack',
#     'is_local': False,
#     'name': 'I Want to Go to Mars',
#     'preview_url': 'https://p.scdn.co/mp3-preview/f6a15349a7084043526dc25489cb087df9e13f22?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:6hwls26jMYEIh6yxiu7Ack'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1q1wfzh2xtpj27TnIAqIvd'},
#       'href': 'https://api.spotify.com/v1/artists/1q1wfzh2xtpj27TnIAqIvd',
#       'id': '1q1wfzh2xtpj27TnIAqIvd',
#       'name': 'Karl Jenkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:1q1wfzh2xtpj27TnIAqIvd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#       'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#       'id': '6i9KFEJuHq78nMsQxeB1vR',
#       'name': 'NDR Radiophilharmonie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2X7XzvKER9pdR7rwYFy6r1'},
#       'href': 'https://api.spotify.com/v1/artists/2X7XzvKER9pdR7rwYFy6r1',
#       'id': '2X7XzvKER9pdR7rwYFy6r1',
#       'name': 'Pop-Up',
#       'type': 'artist',
#       'uri': 'spotify:artist:2X7XzvKER9pdR7rwYFy6r1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#       'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#       'id': '7BuKIq2YqVZhxSdquEnwko',
#       'name': 'Ben Palmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 242946,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3r8SeBYZzeezjNaEYeG8HF'},
#     'href': 'https://api.spotify.com/v1/tracks/3r8SeBYZzeezjNaEYeG8HF',
#     'id': '3r8SeBYZzeezjNaEYeG8HF',
#     'is_local': False,
#     'name': 'Adiemus',
#     'preview_url': 'https://p.scdn.co/mp3-preview/6205a5abec367b9262dd7e06df382ce15f74b43c?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 23,
#     'type': 'track',
#     'uri': 'spotify:track:3r8SeBYZzeezjNaEYeG8HF'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4P70aqttdpJ9vuYFDmf7f6'},
#       'href': 'https://api.spotify.com/v1/artists/4P70aqttdpJ9vuYFDmf7f6',
#       'id': '4P70aqttdpJ9vuYFDmf7f6',
#       'name': 'Vangelis',
#       'type': 'artist',
#       'uri': 'spotify:artist:4P70aqttdpJ9vuYFDmf7f6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0TORlmlTHaneG9k4nWPn0V'},
#       'href': 'https://api.spotify.com/v1/artists/0TORlmlTHaneG9k4nWPn0V',
#       'id': '0TORlmlTHaneG9k4nWPn0V',
#       'name': 'Michael Forster',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TORlmlTHaneG9k4nWPn0V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6j09ytUn8UDWtb9yNYCVPi'},
#       'href': 'https://api.spotify.com/v1/artists/6j09ytUn8UDWtb9yNYCVPi',
#       'id': '6j09ytUn8UDWtb9yNYCVPi',
#       'name': 'The Modern String Quintet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6j09ytUn8UDWtb9yNYCVPi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 166295,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/79zwzKMlhoy0OhZglbLDt3'},
#     'href': 'https://api.spotify.com/v1/tracks/79zwzKMlhoy0OhZglbLDt3',
#     'id': '79zwzKMlhoy0OhZglbLDt3',
#     'is_local': False,
#     'name': 'Chariots of Fire - Piano-Quintet Version',
#     'preview_url': 'https://p.scdn.co/mp3-preview/2aee6eb6d387211effed08a3cbed183d0d542ec1?cid=e99ac0ad2b5c4e329542c2361e28ae40',
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:79zwzKMlhoy0OhZglbLDt3'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 24},
#  'type': 'album',
#  'uri': 'spotify:album:2JgKlCS2glC37XDWreeCy2'}
